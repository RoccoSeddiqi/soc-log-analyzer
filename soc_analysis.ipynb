# %%
# JSON libraries
import pandas as pd
from pandas.io import json

# %%
# Read JSON file
data = json.read_json(path_or_buf="psh_python_webserver_2020-10-2900161507.json", lines=True)

# Displays first 5 rows
data.head()

# Displays all columns
#print(data.columns.values)

# Creates a subset of the columns to be monitored
subset = data[["@timestamp", "EventID", "ProcessName", "CommandLine", "User", "Hostname"]]

# Displays first 5 rows of the subset
subset.head()
# Out:
#                  @timestamp  EventID ProcessName  \
# 0  2020-10-29T12:16:07.900Z     1102         NaN
# 1  2020-10-29T12:16:09.213Z     5158         NaN
# 2  2020-10-29T12:16:09.213Z     5156         NaN
# 3  2020-10-29T12:16:09.914Z     4688         NaN
# 4  2020-10-29T12:16:09.928Z     4690         NaN
#
#                                          CommandLine User      Hostname
# 0                                                NaN  NaN  WORKSTATION5
# 1                                                NaN  NaN  WORKSTATION5
# 2                                                NaN  NaN  WORKSTATION5
# 3  "C:\windows\system32\netsh.exe" advfirewall fi...  NaN  WORKSTATION5
# 4                                                NaN  NaN  WORKSTATION5

# %%
# Temporarily show all rows
with pd.option_context('display.max_rows', None):
    print(subset)  # All rows will be displayed here
# Out:
#                     @timestamp  EventID  \
# 0     2020-10-29T12:16:07.900Z     1102
# 1     2020-10-29T12:16:09.213Z     5158
# 2     2020-10-29T12:16:09.213Z     5156
# 3     2020-10-29T12:16:09.914Z     4688
# 4     2020-10-29T12:16:09.928Z     4690
# 5     2020-10-29T12:16:09.928Z     4658
# 6     2020-10-29T12:16:09.928Z     4656
# 7     2020-10-29T12:16:09.928Z     4663
# 8     2020-10-29T12:16:09.928Z     4658
# 9     2020-10-29T12:16:10.155Z     4690
# 10    2020-10-29T12:16:10.155Z     4658
# 11    2020-10-29T12:16:10.155Z     4656
# 12    2020-10-29T12:16:10.155Z     4663
# 13    2020-10-29T12:16:10.155Z     4658
# 14    2020-10-29T12:16:10.168Z     4690
# 15    2020-10-29T12:16:10.168Z     4658
# 16    2020-10-29T12:16:10.168Z     4656
# 17    2020-10-29T12:16:10.168Z     4663
# 18    2020-10-29T12:16:10.168Z     4658
# 19    2020-10-29T12:16:10.169Z     4690
# 20    2020-10-29T12:16:10.169Z     4658
# 21    2020-10-29T12:16:10.169Z     4656
# ...
